# %%
# IMPORT LIBRARIES

import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
plt.style.use("ggplot")
from matplotlib.pyplot import figure
import numpy as np
# %matplotlib inline
matplotlib.rcParams["figure.figsize"]=(12,10) 


df=pd.read_csv(r"C:\Users\HP\Desktop\project\movies.csv")
# read the data

# %%
# just look the data
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
for col in df.columns:
    pct_missing=np.mean(df.columns.isnull())
    print("{}-{}%".format(col,pct_missing))
# Out:
# name-0.0%
# rating-0.0%
# genre-0.0%
# year-0.0%
# released-0.0%
# score-0.0%
# votes-0.0%
# director-0.0%
# writer-0.0%
# star-0.0%
# country-0.0%
# budget-0.0%
# gross-0.0%
# company-0.0%
# runtime-0.0%

# %%
(df.isnull()).sum()
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
df = df.fillna(0)

# %%
df["budget"]=df["budget"].astype("int64")
df["gross"]=df["gross"].astype("int64")
df["votes"]=df["votes"].astype("int64")

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life      0      Drama  2020
# 7664                                     Dream Round      0     Comedy  2020
# 7665                                   Saving Mbango      0      Drama  2020
# 7666                                    It's Just Us      0      Drama  2020
# 7667                                       Tee em el      0     Horror  2020
#
# ...

# %%
df["corect_year"]=df["released"].astype("str").str.split("(").str[0].str.split(",").str[1]

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life      0      Drama  2020
# 7664                                     Dream Round      0     Comedy  2020
# 7665                                   Saving Mbango      0      Drama  2020
# 7666                                    It's Just Us      0      Drama  2020
# 7667                                       Tee em el      0     Horror  2020
#
# ...

# %%
df.sort_values(by="gross",inplace=False,ascending=False)
# Out:
#                                             name rating    genre  year  \
# 5445                                      Avatar  PG-13   Action  2009
# 7445                           Avengers: Endgame  PG-13   Action  2019
# 3045                                     Titanic  PG-13    Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13   Action  2015
# 7244                      Avengers: Infinity War  PG-13   Action  2018
# ...                                          ...    ...      ...   ...
# 1617                             Mortal Passions      R    Crime  1989
# 1614                              Edge of Sanity      R   Horror  1989
# 1606                                   I, Madman      R  Fantasy  1989
# 1601                        My Twentieth Century      0   Comedy  1989
# 7667                                   Tee em el      0   Horror  2020
#
#                                released  score    votes        director  \
# ...

# %%
pd.set_option()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18332/1113983395.py in <module>
# ----> 1 pd.set_option()
#
# ~\anaconda3\lib\site-packages\pandas\_config\config.py in __call__(self, *args, **kwds)
#     241
#     242     def __call__(self, *args, **kwds):
# --> 243         return self.__func__(*args, **kwds)
#     244
#     245     @property
#
# ~\anaconda3\lib\site-packages\pandas\_config\config.py in _set_option(*args, **kwargs)
#     124     nargs = len(args)
#     125     if not nargs or nargs % 2 != 0:
# --> 126         raise ValueError("Must provide an even number of non-keyword arguments")
#     127
#     128     # default to false
#
# ValueError: Must provide an even number of non-keyword arguments

# %%
df.drop_duplicates()
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life      0      Drama  2020
# 7664                                     Dream Round      0     Comedy  2020
# 7665                                   Saving Mbango      0      Drama  2020
# 7666                                    It's Just Us      0      Drama  2020
# 7667                                       Tee em el      0     Horror  2020
#
# ...

# %%
# budget high correlation
# company high correlation

# %%
# scaterplot\

plt.scatter(x=df["budget"],y=df["gross"])
plt.title("budget vs groos earning")
plt.xlabel("grose")
plt.ylabel("budget of film")
plt.show()

# %%
df=df.sort_values(by="gross",inplace=False,ascending=False)

# %%
df
# Out:
#                                             name rating    genre  year  \
# 5445                                      Avatar  PG-13   Action  2009
# 7445                           Avengers: Endgame  PG-13   Action  2019
# 3045                                     Titanic  PG-13    Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13   Action  2015
# 7244                      Avengers: Infinity War  PG-13   Action  2018
# ...                                          ...    ...      ...   ...
# 1617                             Mortal Passions      R    Crime  1989
# 1614                              Edge of Sanity      R   Horror  1989
# 1606                                   I, Madman      R  Fantasy  1989
# 1601                        My Twentieth Century      0   Comedy  1989
# 7667                                   Tee em el      0   Horror  2020
#
#                                released  score    votes        director  \
# ...

# %%
# plot budget vs gross in seaborn
sns.regplot(x=df.budget,y=df.gross,data=df,line_kws={"color":"blue"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
# lets look at correlation

df.corr()
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.092616  0.222427  0.309212  0.261900  0.116358
# score    0.092616  1.000000  0.407101  0.056863  0.186012  0.394564
# votes    0.222427  0.407101  1.000000  0.486931  0.632870  0.306984
# budget   0.309212  0.056863  0.486931  1.000000  0.750157  0.268372
# gross    0.261900  0.186012  0.632870  0.750157  1.000000  0.244339
# runtime  0.116358  0.394564  0.306984  0.268372  0.244339  1.000000

# %%
correlation_matrix=df.corr()
sns.heatmap(correlation_matrix,annot=True)
plt.title("matrix_correlation of numerical_feature")
plt.xlabel("movie_feature")
plt.ylabel("movie_feature")
plt.show()

# %%
df_numer=df
for col_name in df_numer.columns:
    if(df_numer[col_name].dtype=="object"):
        df_numer[col_name]=df_numer[col_name].astype("category")
        df_numer[col_name]=df_numer[col_name].cat.codes

# %%
df_numer
# Out:
#       name  rating  genre  year  released  score    votes  director  writer  \
# 5445   533       6      0  2009       697    7.8  1100000      1155    1779
# 7445   535       6      0  2019       184    8.4   903000       162     744
# 3045  6896       6      6  1997       705    7.8  1100000      1155    1779
# 6663  5144       6      0  2015       699    7.8   876000      1125    2551
# 7244   536       6      0  2018       193    8.4   897000       162     744
# ...    ...     ...    ...   ...       ...    ...      ...       ...     ...
# 1617  3712       7      5  1989      1278    4.5      274       117      83
# 1614  1745       7     10  1989        56    5.2     1300      1033    1744
# 1606  2691       7      8  1989       258    6.0     2900      2743     947
# 1601  3836       0      4  1989      1161    7.1     1500      1105    1697
# 7667  5394       0     10  2020       392    5.7        7      2165    3345
#
# ...

# %%
df
# Out:
#       name  rating  genre  year  released  score    votes  director  writer  \
# 5445   533       6      0  2009       697    7.8  1100000      1155    1779
# 7445   535       6      0  2019       184    8.4   903000       162     744
# 3045  6896       6      6  1997       705    7.8  1100000      1155    1779
# 6663  5144       6      0  2015       699    7.8   876000      1125    2551
# 7244   536       6      0  2018       193    8.4   897000       162     744
# ...    ...     ...    ...   ...       ...    ...      ...       ...     ...
# 1617  3712       7      5  1989      1278    4.5      274       117      83
# 1614  1745       7     10  1989        56    5.2     1300      1033    1744
# 1606  2691       7      8  1989       258    6.0     2900      2743     947
# 1601  3836       0      4  1989      1161    7.1     1500      1105    1697
# 7667  5394       0     10  2020       392    5.7        7      2165    3345
#
# ...

# %%
correlation_matrix=df.corr()
sns.heatmap(correlation_matrix,annot=True)
plt.title("matrix_correlation of numerical_feature")
plt.xlabel("movie_feature")
plt.ylabel("movie_feature")
plt.show()

# %%
df.corr()
# Out:
#                  name    rating     genre      year  released     score  \
# name         1.000000 -0.008069  0.016355  0.011453 -0.011311  0.016377
# rating      -0.008069  1.000000  0.072423  0.008779  0.016613  0.006192
# genre        0.016355  0.072423  1.000000 -0.081261  0.029822  0.027384
# year         0.011453  0.008779 -0.081261  1.000000 -0.000695  0.092616
# released    -0.011311  0.016613  0.029822 -0.000695  1.000000  0.039814
# score        0.016377  0.006192  0.027384  0.092616  0.039814  1.000000
# votes        0.013038  0.033743 -0.145296  0.222427  0.015878  0.407101
# director     0.009079  0.019483 -0.015258 -0.020795 -0.001478  0.010568
# writer       0.009081 -0.005921  0.006567 -0.008656 -0.002404  0.022098
# star         0.006472  0.013405 -0.005477 -0.027242  0.015777 -0.000026
# country     -0.010737  0.081244 -0.037615 -0.070938 -0.020427 -0.133346
# budget       0.020548 -0.081939 -0.334021  0.309212  0.009145  0.056863
# ...

# %%
corr_mat=df.corr()
unpack_pair=corr_mat.unstack()

# %%
unpack_pair
# Out:
# name         name           1.000000
#              rating        -0.008069
#              genre          0.016355
#              year           0.011453
#              released      -0.011311
#              score          0.016377
#              votes          0.013038
#              director       0.009079
#              writer         0.009081
#              star           0.006472
#              country       -0.010737
#              budget         0.020548
#              gross          0.006989
#              company        0.009211
#              runtime        0.008483
#              corect_year    0.009553
# rating       name          -0.008069
#              rating         1.000000
#              genre          0.072423
#              year           0.008779
#              released       0.016613
#              score          0.006192
#              votes          0.033743
#              director       0.019483
#              writer        -0.005921
# ...

# %%
pd.set_option("display.max_rows",None)

# %%
sorted_pair=unpack_pair.sort_values()

# %%
sorted_pair
# Out:
# budget       genre         -0.334021
# genre        budget        -0.334021
#              gross         -0.234297
# gross        genre         -0.234297
# genre        votes         -0.145296
# votes        genre         -0.145296
# score        country       -0.133346
# country      score         -0.133346
# gross        rating        -0.095450
# rating       gross         -0.095450
# genre        corect_year   -0.082070
# corect_year  genre         -0.082070
# rating       budget        -0.081939
# budget       rating        -0.081939
# genre        year          -0.081261
# year         genre         -0.081261
# country      corect_year   -0.074166
# corect_year  country       -0.074166
# runtime      country       -0.073319
# country      runtime       -0.073319
# company      genre         -0.071067
# genre        company       -0.071067
# year         country       -0.070938
# country      year          -0.070938
# runtime      genre         -0.052914
# ...

# %%
high_corr=sorted_pair[sorted_pair>0.5]

# %%
high_corr
# Out:
# votes        gross          0.632870
# gross        votes          0.632870
# budget       gross          0.750157
# gross        budget         0.750157
# corect_year  year           0.992136
# year         corect_year    0.992136
# name         name           1.000000
# company      company        1.000000
# gross        gross          1.000000
# budget       budget         1.000000
# country      country        1.000000
# star         star           1.000000
# writer       writer         1.000000
# director     director       1.000000
# votes        votes          1.000000
# score        score          1.000000
# released     released       1.000000
# year         year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# corect_year  corect_year    1.000000
# dtype: float64
